# %%
from batdataparser.parser import nw_parse_from_xls

cyc = nw_parse_from_xls('data/cycle-testing_2.48mg.xlsx')
# Out:
# /home/xy_5a/Sources/Notebooks/.venv/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default

# %%
cyc.plot_cv([1, 2, 3])
