# %%
from batdataparser.parser import nw_parse_from_xls

cyc = nw_parse_from_xls('data/cycle-testing_2.48mg.xlsx')
# Out:
# /home/xy_5a/battery_utils/.venv/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
# Cycle_43_2_6 Index(['通道', '循环序号', '充电容量(mAh)', '放电容量(mAh)', '容量保持率(%)'], dtype='object') c
# Statis_43_2_6 Index(['通道', '循环', '步次', '原始步次', '状态', '起始电压(V)', '结束电压(V)', '起始电流(mA)',
#        '结束电流(mA)', '容量(mAh)', '持续时间(h:min:s.ms)', '相对时间(h:min:s.ms)', '绝对时间',
#        '净放电容量(mAh)', '充电容量(mAh)', '放电容量(mAh)', '净放电能量(mWh)', '充电能量(mWh)',
#        '放电能量(mWh)'],
#       dtype='object') s
# Detail_43_2_6 Index(['记录序号', '状态', '跳转', '循环', '步次', '电流(mA)', '电压(V)', '容量(mAh)', '能量(mWh)',
#        '相对时间(h:min:s.ms)', '绝对时间(h:min:s.ms)'],
#       dtype='object') d

# %%
cyc.detail
# Out:
#      Channel  Cycle  Step  OriginalStep Status   起始电压(V)   结束电压(V)  起始电流(mA)  \
# 0          6      1     1             1     搁置  2.650814  2.686198  0.000000
# 1          6      1     2             2   恒流充电  2.740166  3.500035  0.064092
# 2          6      1     3             3     搁置  3.443233  3.206823  0.000000
# 3          6      1     4             4   恒流放电  3.152646  1.499894 -0.064362
# 4          6      1     5             5     搁置  1.559908  1.925187  0.000000
# ..       ...    ...   ...           ...    ...       ...       ...       ...
# 371        6     93   372             4   恒流放电  3.112209  1.499961 -0.064294
# 372        6     93   373             5     搁置  1.682157  1.798495  0.000000
# 373        6     94   374             2   恒流充电  1.987885  3.500145  0.064300
# 374        6     94   375             3     搁置  3.438579  3.172642  0.000000
# 375        6     94   376             4   恒流放电  3.114292  1.842582 -0.064366
#
#      结束电流(mA)   容量(mAh) 持续时间(h:min:s.ms) 相对时间(h:min:s.ms)  \
# 0    0.000000  0.000000      3:00:00.000      3:00:00.000
# 1    0.064511  0.002468      0:02:17.700      0:02:17.700
# 2    0.000000  0.000000      0:01:00.000      0:01:00.000
# 3   -0.064493  0.248973      3:51:37.300      3:51:37.300
# 4    0.000000  0.000000      0:01:00.000      0:01:00.000
# ..        ...       ...              ...              ...
# 371 -0.064495  0.259389      4:01:18.300      4:01:18.300
# 372  0.000000  0.000000      0:01:00.000      0:01:00.000
# 373  0.064505  0.257909      3:59:53.600      3:59:53.600
# 374  0.000000  0.000000      0:01:00.000      0:01:00.000
# 375 -0.064501  0.219658      3:24:20.000      3:24:20.000
#
#                     绝对时间  净放电容量(mAh)  充电容量(mAh)  放电容量(mAh)  净放电能量(mWh)  \
# 0    2024-09-21 14:04:52    0.000000   0.000000   0.000000    0.000000
# 1    2024-09-21 17:04:52   -0.002468   0.002468   0.000000   -0.007824
# 2    2024-09-21 17:07:10    0.000000   0.000000   0.000000    0.000000
# 3    2024-09-21 17:08:10    0.248973   0.000000   0.248973    0.526734
# 4    2024-09-21 20:59:46    0.000000   0.000000   0.000000    0.000000
# ..                   ...         ...        ...        ...         ...
# 371  2024-10-24 04:05:58    0.259389   0.000000   0.259389    0.565560
# 372  2024-10-24 08:07:16    0.000000   0.000000   0.000000    0.000000
# 373  2024-10-24 08:08:16   -0.257909   0.257909   0.000000   -0.693936
# 374  2024-10-24 12:08:09    0.000000   0.000000   0.000000    0.000000
# 375  2024-10-24 12:09:09    0.219658   0.000000   0.219658    0.511875
#
#      充电能量(mWh)  放电能量(mWh)
# 0     0.000000   0.000000
# 1     0.007824   0.000000
# 2     0.000000   0.000000
# 3     0.000000   0.526734
# 4     0.000000   0.000000
# ..         ...        ...
# 371   0.000000   0.565560
# 372   0.000000   0.000000
# 373   0.693936   0.000000
# 374   0.000000   0.000000
# 375   0.000000   0.511875
#
# [376 rows x 19 columns]
